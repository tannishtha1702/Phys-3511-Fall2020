# %% [markdown]
# # Assignment 5:  Due 10/7
#
# In this assignment you will become familiar with the Pandas library through the exploration of a Nobel prize data set.
#
# This data set was taken from the Kaggle website (https://www.kaggle.com/). If you are interested in data science and / or analysis, this website offers tons of data sets in various formats that you can access. They even post compititions that you can enter, some with money prizes awarded.
#
#
# The libraries needed for this assignment are listed below.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/anaconda3/lib/python3.7/site-packages (from pandas) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/anaconda3/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /opt/anaconda3/lib/python3.7/site-packages (from pandas) (1.18.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %% [markdown]
# # 1a)
#
# Read in the data set 'data/nobel.csv' into a DataFrame using Pandas .

# %%
df = pd.read_csv("/Users/tannishtha_nandi/Desktop/Physics Computing/Phys-3511-Fall2020-master/Module05/data/nobel.csv")
df
# Out:
#      year    category                                           prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 906  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 907  2016       Peace                      The Nobel Peace Prize 2016
# 908  2016     Physics                 The Nobel Prize in Physics 2016
# 909  2016     Physics                 The Nobel Prize in Physics 2016
# 910  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# 0    "in recognition of the extraordinary services ...         1/1
# 1    "in special recognition of his poetic composit...         1/1
# 2    "for his work on serum therapy, especially its...         1/1
# 3                                                  NaN         1/2
# 4                                                  NaN         1/2
# ..                                                 ...         ...
# 906  "for his discoveries of mechanisms for autophagy"         1/1
# 907  "for his resolute efforts to bring the country...         1/1
# 908  "for theoretical discoveries of topological ph...         1/2
# 909  "for theoretical discoveries of topological ph...         1/4
# 910  "for theoretical discoveries of topological ph...         1/4
#
#      laureate_id laureate_type                     full_name  birth_date  \
# 0            160    Individual  Jacobus Henricus van 't Hoff  1852-08-30
# 1            569    Individual               Sully Prudhomme  1839-03-16
# 2            293    Individual        Emil Adolf von Behring  1854-03-15
# 3            462    Individual             Jean Henry Dunant  1828-05-08
# 4            463    Individual                Frédéric Passy  1822-05-20
# ..           ...           ...                           ...         ...
# 906          927    Individual              Yoshinori Ohsumi  1945-02-09
# 907          934    Individual            Juan Manuel Santos  1951-08-10
# 908          928    Individual             David J. Thouless  1934-09-21
# 909          929    Individual          F. Duncan M. Haldane  1951-09-14
# 910          930    Individual         J. Michael Kosterlitz  1943-06-22
#
#             birth_city     birth_country   sex              organization_name  \
# 0            Rotterdam       Netherlands  Male              Berlin University
# 1                Paris            France  Male                            NaN
# 2    Hansdorf (Lawice)  Prussia (Poland)  Male             Marburg University
# 3               Geneva       Switzerland  Male                            NaN
# 4                Paris            France  Male                            NaN
# ..                 ...               ...   ...                            ...
# 906            Fukuoka             Japan  Male  Tokyo Institute of Technology
# 907             Bogotá          Colombia  Male                            NaN
# 908           Bearsden    United Kingdom  Male       University of Washington
# 909             London    United Kingdom  Male           Princeton University
# 910           Aberdeen    United Kingdom  Male               Brown University
#
#     organization_city      organization_country  death_date death_city  \
# 0              Berlin                   Germany  1911-03-01     Berlin
# 1                 NaN                       NaN  1907-09-07   Châtenay
# 2             Marburg                   Germany  1917-03-31    Marburg
# 3                 NaN                       NaN  1910-10-30     Heiden
# 4                 NaN                       NaN  1912-06-12      Paris
# ..                ...                       ...         ...        ...
# 906             Tokyo                     Japan         NaN        NaN
# 907               NaN                       NaN         NaN        NaN
# 908       Seattle, WA  United States of America         NaN        NaN
# 909     Princeton, NJ  United States of America         NaN        NaN
# 910    Providence, RI  United States of America         NaN        NaN
#
#     death_country
# 0         Germany
# 1          France
# 2         Germany
# 3     Switzerland
# 4          France
# ..            ...
# 906           NaN
# 907           NaN
# 908           NaN
# 909           NaN
# 910           NaN
#
# [911 rows x 18 columns]

# %% [markdown]
# # 1b)
#
# Display below the output from the DataFrame functions *info*.

# %%
df.info
# Out:
# <bound method DataFrame.info of      year    category                                           prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 906  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 907  2016       Peace                      The Nobel Peace Prize 2016
# 908  2016     Physics                 The Nobel Prize in Physics 2016
# 909  2016     Physics                 The Nobel Prize in Physics 2016
# 910  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# 0    "in recognition of the extraordinary services ...         1/1
# 1    "in special recognition of his poetic composit...         1/1
# 2    "for his work on serum therapy, especially its...         1/1
# 3                                                  NaN         1/2
# 4                                                  NaN         1/2
# ..                                                 ...         ...
# 906  "for his discoveries of mechanisms for autophagy"         1/1
# 907  "for his resolute efforts to bring the country...         1/1
# 908  "for theoretical discoveries of topological ph...         1/2
# 909  "for theoretical discoveries of topological ph...         1/4
# 910  "for theoretical discoveries of topological ph...         1/4
#
#      laureate_id laureate_type                     full_name  birth_date  \
# 0            160    Individual  Jacobus Henricus van 't Hoff  1852-08-30
# 1            569    Individual               Sully Prudhomme  1839-03-16
# 2            293    Individual        Emil Adolf von Behring  1854-03-15
# 3            462    Individual             Jean Henry Dunant  1828-05-08
# 4            463    Individual                Frédéric Passy  1822-05-20
# ..           ...           ...                           ...         ...
# 906          927    Individual              Yoshinori Ohsumi  1945-02-09
# 907          934    Individual            Juan Manuel Santos  1951-08-10
# 908          928    Individual             David J. Thouless  1934-09-21
# 909          929    Individual          F. Duncan M. Haldane  1951-09-14
# 910          930    Individual         J. Michael Kosterlitz  1943-06-22
#
#             birth_city     birth_country   sex              organization_name  \
# 0            Rotterdam       Netherlands  Male              Berlin University
# 1                Paris            France  Male                            NaN
# 2    Hansdorf (Lawice)  Prussia (Poland)  Male             Marburg University
# 3               Geneva       Switzerland  Male                            NaN
# 4                Paris            France  Male                            NaN
# ..                 ...               ...   ...                            ...
# 906            Fukuoka             Japan  Male  Tokyo Institute of Technology
# 907             Bogotá          Colombia  Male                            NaN
# 908           Bearsden    United Kingdom  Male       University of Washington
# 909             London    United Kingdom  Male           Princeton University
# 910           Aberdeen    United Kingdom  Male               Brown University
#
#     organization_city      organization_country  death_date death_city  \
# 0              Berlin                   Germany  1911-03-01     Berlin
# 1                 NaN                       NaN  1907-09-07   Châtenay
# 2             Marburg                   Germany  1917-03-31    Marburg
# 3                 NaN                       NaN  1910-10-30     Heiden
# 4                 NaN                       NaN  1912-06-12      Paris
# ..                ...                       ...         ...        ...
# 906             Tokyo                     Japan         NaN        NaN
# 907               NaN                       NaN         NaN        NaN
# 908       Seattle, WA  United States of America         NaN        NaN
# 909     Princeton, NJ  United States of America         NaN        NaN
# 910    Providence, RI  United States of America         NaN        NaN
#
#     death_country
# 0         Germany
# 1          France
# 2         Germany
# 3     Switzerland
# 4          France
# ..            ...
# 906           NaN
# 907           NaN
# 908           NaN
# 909           NaN
# 910           NaN
#
# [911 rows x 18 columns]>

# %% [markdown]
# # 1c)
#
# Show the first 5 listings of the dataset.

# %%
df.head(5)
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   laureate_type                     full_name  birth_date         birth_city  \
# 0    Individual  Jacobus Henricus van 't Hoff  1852-08-30          Rotterdam
# 1    Individual               Sully Prudhomme  1839-03-16              Paris
# 2    Individual        Emil Adolf von Behring  1854-03-15  Hansdorf (Lawice)
# 3    Individual             Jean Henry Dunant  1828-05-08             Geneva
# 4    Individual                Frédéric Passy  1822-05-20              Paris
#
#       birth_country   sex   organization_name organization_city  \
# 0       Netherlands  Male   Berlin University            Berlin
# 1            France  Male                 NaN               NaN
# 2  Prussia (Poland)  Male  Marburg University           Marburg
# 3       Switzerland  Male                 NaN               NaN
# 4            France  Male                 NaN               NaN
#
#   organization_country  death_date death_city death_country
# 0              Germany  1911-03-01     Berlin       Germany
# 1                  NaN  1907-09-07   Châtenay        France
# 2              Germany  1917-03-31    Marburg       Germany
# 3                  NaN  1910-10-30     Heiden   Switzerland
# 4                  NaN  1912-06-12      Paris        France

# %% [markdown]
# # Problem 2
#
# How many null ('NaN') values there are in each *catagory*? What is the total number of Null values in the DataFrame?

# %%
sincat= df.isnull().sum()
print ('Sum In Each Category \n\n', sincat)
# Out:
# Sum In Each Category
#
#  year                      0
# category                  0
# prize                     0
# motivation               88
# prize_share               0
# laureate_id               0
# laureate_type             0
# full_name                 0
# birth_date               28
# birth_city               28
# birth_country            26
# sex                      26
# organization_name       246
# organization_city       244
# organization_country    244
# death_date              318
# death_city              335
# death_country           329
# dtype: int64

# %%
ts = df.isnull().sum().cumsum()
print(ts)
print ('\n\n\nTotal Sum of all Categories:', ts[-1])
# Out:
# year                       0
# category                   0
# prize                      0
# motivation                88
# prize_share               88
# laureate_id               88
# laureate_type             88
# full_name                 88
# birth_date               116
# birth_city               144
# birth_country            170
# sex                      196
# organization_name        442
# organization_city        686
# organization_country     930
# death_date              1248
# death_city              1583
# death_country           1912
# dtype: int64
#
#
#
# Total Sum of all Categories: 1912

# %% [markdown]
# # Problem 3
#
# Make a histogram of the number of nobel prizes awarded per year. Around which decade (1900, 1910, 1920, ...) were the least amount of prizes awarded?

# %%
df.hist('year',bins=40)

print('Least Number of Nobel Prizes were awarded in the decade of 1940');
# Out:
# <img src="data:image/png;base64,..." width="640">
# Least Number of Nobel Prizes were awarded in the decade of 1940

# %% [markdown]
# # Problem 4
#
# Use groupby method to printout the number of prizes awarded to each category. Which categroy has the most prizes?

# %%
df.groupby('category').agg('count')
# Out:
#             year  prize  motivation  prize_share  laureate_id  laureate_type  \
# category
# Chemistry    175    175         175          175          175            175
# Economics     78     78          78           78           78             78
# Literature   113    113         113          113          113            113
# Medicine     211    211         211          211          211            211
# Peace        130    130          42          130          130            130
# Physics      204    204         204          204          204            204
#
#             full_name  birth_date  birth_city  birth_country  sex  \
# category
# Chemistry         175         174         175            175  175
# Economics          78          78          78             78   78
# Literature        113         113         112            113  113
# Medicine          211         211         211            211  211
# Peace             130         104         103            104  104
# Physics           204         203         204            204  204
#
#             organization_name  organization_city  organization_country  \
# category
# Chemistry                 173                173                   174
# Economics                  76                 76                    76
# Literature                  0                  0                     0
# Medicine                  210                211                   210
# Peace                       4                  4                     4
# Physics                   202                203                   203
#
#             death_date  death_city  death_country
# category
# Chemistry          114         111            111
# Economics           40          40             40
# Literature          96          96             96
# Medicine           147         143            143
# Peace               72          69             70
# Physics            124         117            122

# %%
max = df.groupby('category').agg('count').max()
print(max['prize'])
print('The Field of Medicine has the most number of Nobel Prizes awarded, that is',max['prize'],'prizes')
# Out:
# 211
# The Field of Medicine has the most number of Nobel Prizes awarded, that is 211 prizes

# %% [markdown]
# # Problem 5
#
# Find percentage of the prizes were awarded to 1, 2, 3, and 4 people? Meaning what percentage of 1/1, 1/2, 1/3, and 1/4 prize_shares are there?

# %%
df.groupby('prize_share').agg('count')
print(prizeshare)

prizeshare1= (344/911)*100
prizeshare2= (306/911)*100
prizeshare3= (201/911)*100
prizeshare4= (60/911)*100
print('\n\n')
print('Percentage of 1/1 Prize share:',prizeshare1,'%')
print('Percentage of 1/2 Prize share:',prizeshare2,'%')
print('Percentage of 1/3 Prize share:',prizeshare3,'%')
print('Percentage of 1/4 Prize share:',prizeshare4,'%')
# Out:
#              year  category  prize  motivation  laureate_id  laureate_type  \
# prize_share
# 1/1           344       344    344         294          344            344
# 1/2           306       306    306         268          306            306
# 1/3           201       201    201         201          201            201
# 1/4            60        60     60          60           60             60
#
#              full_name  birth_date  birth_city  birth_country  sex  \
# prize_share
# 1/1                344         328         326            328  328
# 1/2                306         295         296            296  296
# 1/3                201         200         201            201  201
# 1/4                 60          60          60             60   60
#
#              organization_name  organization_city  organization_country  \
# prize_share
# 1/1                        175                175                   174
# 1/2                        237                239                   239
# 1/3                        195                194                   195
# 1/4                         58                 59                    59
#
#              death_date  death_city  death_country
# prize_share
# 1/1                 275         269            271
# 1/2                 197         190            193
# 1/3                  96          92             93
# 1/4                  25          25             25
#
#
#
# Percentage of 1/1 Prize share: 37.76070252469814 %
# Percentage of 1/2 Prize share: 33.589462129527995 %
# Percentage of 1/3 Prize share: 22.063666300768386 %
# Percentage of 1/4 Prize share: 6.586169045005488 %

# %% [markdown]
# # Problem 6
#
# Determine how many males and females won the prize. Does the sum of male and female prizes add up to the total entries? If not, why?
#
# On the same graph make histograms for the numbber of males and females that won the prize each year.

# %%
male = df[df['sex']== 'Male']
m=male.count()
print("Males who won Nobel Prize:",m['sex'])
female = df[df ['sex']!='Male']
f=female.count()
print("Females who won Nobel Prize:",f['sex'])
print('The number of males and females winning the Nobel Prize does not add up to the total entries as no Nobel Prizes were awarded in certain years')
# Out:
# Males who won Nobel Prize: 836
# Females who won Nobel Prize: 49
# The number of males and females winning the Nobel Prize does not add up to the total entries as no Nobel Prizes were awarded in certain years

# %%
fig = plt.figure('Males and Females')
plt.hist(male.year, bins=100,alpha = 0.5, label ='Males')
plt.hist(female.year, bins=100,alpha = 0.5, label = 'Females')
plt.ylabel("Frequency")
plt.xlabel('Males and Females')
plt.title("Males and Females Distribution in Nobel Prize Winner")
plt.legend();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Problem 7
#
# How many prizes were won by those whose birth country was United States of America?

# %%
dfcountry = df['birth_country']== 'United States of America'
dfcountry.sum()
print('The number of prizes won by those whose birth country was United States of America are:',dfcountry.sum())
# Out:
# The number of prizes won by those whose birth country was United States of America are: 259

# %% [markdown]
# # Problem 8
#
# Determine the age that each of the prize winners was when they won the prize. Find the youngest and oldest to win the prize. Find the mean age to win the prize, and the standard deviation of it. Make a histogram of the age each person was when they won the prize.
#
# ### Hint: You can use Pandas DatetimeIndex method to extract the year from the date format yyyy-mm-dd
# > pd.DatetimeIndex(date).year
#
# Where *date* is given in a formate like year-month-day, the above will returen the year, hence the *.year* in the call above. Use 'shit+tab' on pandas.DatetimeIndex to learn more.

# %%
age = df['year']-(pd.DatetimeIndex(df['birth_date']).year)
print(age)

fig = plt.figure('Age')
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.hist(age,bins =40)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age of Nobel Prize Winners");
# Out:
# 0      49.0
# 1      62.0
# 2      47.0
# 3      73.0
# 4      79.0
#        ...
# 906    71.0
# 907    65.0
# 908    82.0
# 909    65.0
# 910    73.0
# Length: 911, dtype: float64
# <img src="data:image/png;base64,..." width="640">

# %%
age.min()
print('Minimum age or the Youngest age to win Nobel Prize is',age.min())
# Out:
# Minimum age or the Youngest age to win Nobel Prize is 17.0

# %%
age.max()
print('Maximum age or the Oldest age to win Nobel Prize is',age.max())
# Out:
# Maximum age or the Oldest age to win Nobel Prize is 90.0

# %%
age.mean()
print('Mean age to win Nobel Prize is',age.mean())
# Out:
# Mean age to win Nobel Prize is 59.453001132502834

# %%
age.std()
print('Standard Deviation of the age to win Nobel Prize is',age.std())
# Out:
# Standard Deviation of the age to win Nobel Prize is 12.39929042786365

# %% [markdown]
# # Problem 9
#
# Make a copy of the current DataFrame. Then drop the column *lauret_id* from the copied DataFrame (do this inplace so this column is gone).

# %%
dfnew = df.copy()

# %%
dfnew.drop('laureate_id',axis=1,inplace=True)
dfnew
# Out:
#      year    category                                           prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 906  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 907  2016       Peace                      The Nobel Peace Prize 2016
# 908  2016     Physics                 The Nobel Prize in Physics 2016
# 909  2016     Physics                 The Nobel Prize in Physics 2016
# 910  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# 0    "in recognition of the extraordinary services ...         1/1
# 1    "in special recognition of his poetic composit...         1/1
# 2    "for his work on serum therapy, especially its...         1/1
# 3                                                  NaN         1/2
# 4                                                  NaN         1/2
# ..                                                 ...         ...
# 906  "for his discoveries of mechanisms for autophagy"         1/1
# 907  "for his resolute efforts to bring the country...         1/1
# 908  "for theoretical discoveries of topological ph...         1/2
# 909  "for theoretical discoveries of topological ph...         1/4
# 910  "for theoretical discoveries of topological ph...         1/4
#
#     laureate_type                     full_name  birth_date  \
# 0      Individual  Jacobus Henricus van 't Hoff  1852-08-30
# 1      Individual               Sully Prudhomme  1839-03-16
# 2      Individual        Emil Adolf von Behring  1854-03-15
# 3      Individual             Jean Henry Dunant  1828-05-08
# 4      Individual                Frédéric Passy  1822-05-20
# ..            ...                           ...         ...
# 906    Individual              Yoshinori Ohsumi  1945-02-09
# 907    Individual            Juan Manuel Santos  1951-08-10
# 908    Individual             David J. Thouless  1934-09-21
# 909    Individual          F. Duncan M. Haldane  1951-09-14
# 910    Individual         J. Michael Kosterlitz  1943-06-22
#
#             birth_city     birth_country   sex              organization_name  \
# 0            Rotterdam       Netherlands  Male              Berlin University
# 1                Paris            France  Male                            NaN
# 2    Hansdorf (Lawice)  Prussia (Poland)  Male             Marburg University
# 3               Geneva       Switzerland  Male                            NaN
# 4                Paris            France  Male                            NaN
# ..                 ...               ...   ...                            ...
# 906            Fukuoka             Japan  Male  Tokyo Institute of Technology
# 907             Bogotá          Colombia  Male                            NaN
# 908           Bearsden    United Kingdom  Male       University of Washington
# 909             London    United Kingdom  Male           Princeton University
# 910           Aberdeen    United Kingdom  Male               Brown University
#
#     organization_city      organization_country  death_date death_city  \
# 0              Berlin                   Germany  1911-03-01     Berlin
# 1                 NaN                       NaN  1907-09-07   Châtenay
# 2             Marburg                   Germany  1917-03-31    Marburg
# 3                 NaN                       NaN  1910-10-30     Heiden
# 4                 NaN                       NaN  1912-06-12      Paris
# ..                ...                       ...         ...        ...
# 906             Tokyo                     Japan         NaN        NaN
# 907               NaN                       NaN         NaN        NaN
# 908       Seattle, WA  United States of America         NaN        NaN
# 909     Princeton, NJ  United States of America         NaN        NaN
# 910    Providence, RI  United States of America         NaN        NaN
#
#     death_country
# 0         Germany
# 1          France
# 2         Germany
# 3     Switzerland
# 4          France
# ..            ...
# 906           NaN
# 907           NaN
# 908           NaN
# 909           NaN
# 910           NaN
#
# [911 rows x 17 columns]

# %% [markdown]
# # Problem 10
#
# Add the age column you calculated in Problem 8 to the DataFrame.

# %%
df['age']=age
df
# Out:
#      year    category                                           prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 906  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 907  2016       Peace                      The Nobel Peace Prize 2016
# 908  2016     Physics                 The Nobel Prize in Physics 2016
# 909  2016     Physics                 The Nobel Prize in Physics 2016
# 910  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# 0    "in recognition of the extraordinary services ...         1/1
# 1    "in special recognition of his poetic composit...         1/1
# 2    "for his work on serum therapy, especially its...         1/1
# 3                                                  NaN         1/2
# 4                                                  NaN         1/2
# ..                                                 ...         ...
# 906  "for his discoveries of mechanisms for autophagy"         1/1
# 907  "for his resolute efforts to bring the country...         1/1
# 908  "for theoretical discoveries of topological ph...         1/2
# 909  "for theoretical discoveries of topological ph...         1/4
# 910  "for theoretical discoveries of topological ph...         1/4
#
#      laureate_id laureate_type                     full_name  birth_date  \
# 0            160    Individual  Jacobus Henricus van 't Hoff  1852-08-30
# 1            569    Individual               Sully Prudhomme  1839-03-16
# 2            293    Individual        Emil Adolf von Behring  1854-03-15
# 3            462    Individual             Jean Henry Dunant  1828-05-08
# 4            463    Individual                Frédéric Passy  1822-05-20
# ..           ...           ...                           ...         ...
# 906          927    Individual              Yoshinori Ohsumi  1945-02-09
# 907          934    Individual            Juan Manuel Santos  1951-08-10
# 908          928    Individual             David J. Thouless  1934-09-21
# 909          929    Individual          F. Duncan M. Haldane  1951-09-14
# 910          930    Individual         J. Michael Kosterlitz  1943-06-22
#
#             birth_city     birth_country   sex              organization_name  \
# 0            Rotterdam       Netherlands  Male              Berlin University
# 1                Paris            France  Male                            NaN
# 2    Hansdorf (Lawice)  Prussia (Poland)  Male             Marburg University
# 3               Geneva       Switzerland  Male                            NaN
# 4                Paris            France  Male                            NaN
# ..                 ...               ...   ...                            ...
# 906            Fukuoka             Japan  Male  Tokyo Institute of Technology
# 907             Bogotá          Colombia  Male                            NaN
# 908           Bearsden    United Kingdom  Male       University of Washington
# 909             London    United Kingdom  Male           Princeton University
# 910           Aberdeen    United Kingdom  Male               Brown University
#
#     organization_city      organization_country  death_date death_city  \
# 0              Berlin                   Germany  1911-03-01     Berlin
# 1                 NaN                       NaN  1907-09-07   Châtenay
# 2             Marburg                   Germany  1917-03-31    Marburg
# 3                 NaN                       NaN  1910-10-30     Heiden
# 4                 NaN                       NaN  1912-06-12      Paris
# ..                ...                       ...         ...        ...
# 906             Tokyo                     Japan         NaN        NaN
# 907               NaN                       NaN         NaN        NaN
# 908       Seattle, WA  United States of America         NaN        NaN
# 909     Princeton, NJ  United States of America         NaN        NaN
# 910    Providence, RI  United States of America         NaN        NaN
#
#     death_country   age
# 0         Germany  49.0
# 1          France  62.0
# 2         Germany  47.0
# 3     Switzerland  73.0
# 4          France  79.0
# ..            ...   ...
# 906           NaN  71.0
# 907           NaN  65.0
# 908           NaN  82.0
# 909           NaN  65.0
# 910           NaN  73.0
#
# [911 rows x 19 columns]
